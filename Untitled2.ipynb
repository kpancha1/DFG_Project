# %%
import pandas as pd
df = pd.read_csv("data/final.csv", sep = "\t")
df
# Out:
#      Unnamed: 0         City     County  Population  Violent\ncrime  \
# 0             0        Akron     Summit    197882.0          1782.0
# 1             1     Alliance      Stark     21536.0            28.0
# 2             2      Amherst     Lorain     12166.0             4.0
# 3             3      Ashland    Ashland     20410.0            33.0
# 4             4       Aurora    Portage     16319.0             1.0
# ..          ...          ...        ...         ...             ...
# 107         107  Westerville   Franklin     40903.0            74.0
# 108         108    Wickliffe       Lake     12758.0            16.0
# 109         109   Willoughby       Lake     23081.0            19.0
# 110         110        Xenia     Greene     26926.0            74.0
# 111         111   Zanesville  Muskingum     25346.0            89.0
#
#      Murder and\nnonnegligent\nmanslaughter  Rape1  Robbery  \
# 0                                      27.0  181.0    328.0
# ...
