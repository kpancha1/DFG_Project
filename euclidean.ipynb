# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("data/final.csv", "\t")

# %%
df
# Out:
#      Unnamed: 0            City     County  Population  Violent\ncrime  \
# 0             0             Ada     Hardin      5509.0             3.0
# 1             1           Akron     Summit    197882.0          1782.0
# 2             2        Alliance      Stark     21536.0            28.0
# 3             3         Amherst     Lorain     12166.0             4.0
# 4             4         Arcanum      Darke      2006.0             0.0
# ..          ...             ...        ...         ...             ...
# 158         158      Willoughby       Lake     23081.0            19.0
# 159         159         Windham    Portage      2210.0             4.0
# 160         160           Xenia     Greene     26926.0            74.0
# 161         161  Yellow Springs     Greene      3727.0             7.0
# 162         162      Zanesville  Muskingum     25346.0            89.0
#
#      Murder and\nnonnegligent\nmanslaughter  Rape1  Robbery  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'City', 'County', 'Population', 'Violent\ncrime',
#        'Murder and\nnonnegligent\nmanslaughter', 'Rape1', 'Robbery',
#        'Aggravated\nassault', 'Property\ncrime', 'Burglary', 'Larceny-\ntheft',
#        'Motor\nvehicle\ntheft', 'Arson', 'skl_PI_ranking',
#        'building_PI_ranking', 'SAFMR\n0BR', 'SAFMR\n1BR', 'SAFMR\n2BR',
#        'SAFMR\n3BR', 'SAFMR\n4BR', 'medinc_23p1', 'medinc_23p2', 'medinc_23p3',
#        'medinc_23p4', 'medinc_23p5', 'medinc_23p6', 'medinc_23p7',
#        'medinc_23p8', 'Total Students', 'Free and reduced lunch'],
#       dtype='object')

# %%
columns_to_scale = ['Population', 'Violent\ncrime', 'Murder and\nnonnegligent\nmanslaughter', 'Rape1', 'Robbery', 'Aggravated\nassault', 'Property\ncrime', 'Burglary', 'Larceny-\ntheft',
       'Motor\nvehicle\ntheft', 'Arson', 'skl_PI_ranking',
       'building_PI_ranking', 'SAFMR\n0BR', 'SAFMR\n1BR', 'SAFMR\n2BR',
       'SAFMR\n3BR', 'SAFMR\n4BR', 'medinc_23p1', 'medinc_23p2', 'medinc_23p3',
       'medinc_23p4', 'medinc_23p5', 'medinc_23p6', 'medinc_23p7',
       'medinc_23p8', 'Total Students', 'Free and reduced lunch']

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler to your data and transform it
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])
df
# Out:
#      Unnamed: 0            City     County  Population  Violent\ncrime  \
# 0             0             Ada     Hardin    0.012986        0.000518
# 1             1           Akron     Summit    0.517543        0.307719
# 2             2        Alliance      Stark    0.055021        0.004835
# 3             3         Amherst     Lorain    0.030446        0.000691
# 4             4         Arcanum      Darke    0.003798        0.000000
# ..          ...             ...        ...         ...             ...
# 158         158      Willoughby       Lake    0.059073        0.003281
# 159         159         Windham    Portage    0.004333        0.000691
# 160         160           Xenia     Greene    0.069158        0.012778
# 161         161  Yellow Springs     Greene    0.008312        0.001209
# 162         162      Zanesville  Muskingum    0.065014        0.015369
#
#      Murder and\nnonnegligent\nmanslaughter     Rape1   Robbery  \
# ...
